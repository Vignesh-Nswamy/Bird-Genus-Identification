# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import numpy
import os
import librosa
import tensorflow as tf
# Out:
# <p style="color: red;">
# The default version of TensorFlow in Colab will soon switch to TensorFlow 2.x.<br>
# We recommend you <a href="https://www.tensorflow.org/guide/migrate" target="_blank">upgrade</a> now
# or ensure your notebook will continue to use TensorFlow 1.x via the <code>%tensorflow_version 1.x</code> magic:
# <a href="https://colab.research.google.com/notebooks/tensorflow_version.ipynb" target="_blank">more info</a>.</p>

# %%
parent_path = '/content/drive/My Drive/Experimental Projects/Bird Song/'

# %%
def read_npz(file_name):
    file_path = parent_path + file_name + '.npz'
    numpy_set = numpy.load(file_path)
    return numpy_set['arr_0'], numpy_set['arr_1']

# %%
X_train_1, y_train_1 = read_npz('train_data_1')
X_train_2, y_train_2 = read_npz('train_data_2')
X_train_3, y_train_3 = read_npz('train_data_3')
X_train_4, y_train_4 = read_npz('train_data_4')
X_train_5, y_train_5 = read_npz('train_data_5')
X_train_6, y_train_6 = read_npz('train_data_6')

# %%
x_train = numpy.concatenate((X_train_1, X_train_2, X_train_3, X_train_4, X_train_5, X_train_6), axis=0)
y_train = numpy.concatenate((y_train_1, y_train_2, y_train_3, y_train_4, y_train_5, y_train_6), axis=0)

# %%
import gc
del X_train_1, X_train_2, X_train_3, X_train_4, X_train_5, X_train_6
del y_train_1, y_train_2, y_train_3, y_train_4, y_train_5, y_train_6
gc.collect()
# Out:
# 182

# %%
x_test, y_test = read_npz('test_data')

# %%
def init_parallel_crnn(input_shape):  
    n_classes = 182
    conv_kernel_size = (3, 1)
    lstm_hidden_units = 64
    # Input layer
    input_layer = tf.keras.layers.Input(input_shape, name='input')
    # Convolutional branch
    # convolution 1
    conv_1 = tf.keras.layers.Conv2D(16, conv_kernel_size, activation='relu')(input_layer)
    max_pool_1 = tf.keras.layers.MaxPooling2D(2, 2)(conv_1)
    # convolution 2
    conv_2 = tf.keras.layers.Conv2D(32, conv_kernel_size, activation='relu')(max_pool_1)
    max_pool_2 = tf.keras.layers.MaxPooling2D(2,2)(conv_2)
    # dropout_1 = tf.keras.layers.Dropout(0.5)(max_pool_2)
    # convolution 3
    conv_3 = tf.keras.layers.Conv2D(64, conv_kernel_size, activation='relu')(max_pool_2)
    max_pool_3 = tf.keras.layers.MaxPooling2D(2,2)(conv_3)
    # convolution 4
    conv_4 = tf.keras.layers.Conv2D(64, conv_kernel_size, activation='relu')(max_pool_3)
    max_pool_4 = tf.keras.layers.MaxPooling2D(4,4)(conv_4)
    # dropout_2 = tf.keras.layers.Dropout(0.5)(max_pool_4)
    conv_5 = tf.keras.layers.Conv2D(64, conv_kernel_size, activation='relu')(max_pool_4)
    max_pool_5 = tf.keras.layers.MaxPooling2D((4, 4))(conv_5)
    # Flatten
    flatten_1 = tf.keras.layers.Flatten()(max_pool_5)
    # Recurrent branch
    max_pool_lstm = tf.keras.layers.MaxPooling2D(2, 2)(input_layer)
    squeeze_lambda = tf.keras.layers.Lambda(lambda x: tf.keras.backend.squeeze(x, axis= -1))(max_pool_lstm)
    lstm = tf.keras.layers.Bidirectional(tf.keras.layers.LSTM(lstm_hidden_units))(squeeze_lambda)
    # Concatenate convolutional and recurrent branches
    combine_cnn_rnn = tf.keras.layers.concatenate([flatten_1, lstm], axis=-1, name ='combine')
    # dropout_3 = tf.keras.layers.Dropout(0.5)(combine_cnn_rnn)
    output_layer = tf.keras.layers.Dense(n_classes, activation='softmax')(combine_cnn_rnn)
    model = tf.keras.models.Model(input_layer, output_layer)

    print(model.summary())
    return model

# %%
def init_crnn(input_shape):  
    n_classes = 182
    n_hidden = 200
    conv_kernel_size = (3, 1)
    lstm_hidden_units = 96
    num_conv_layers = 6
    layers = []
    layers.append(tf.keras.layers.Input(input_shape, name='input'))
    for i in range(num_conv_layers):
        layers.append(tf.keras.layers.Conv1D(filters=56, kernel_size=5, kernel_regularizer=tf.keras.regularizers.l2(0.001), name='conv_'+str(i)))
        layers.append(tf.keras.layers.BatchNormalization(momentum=0.9, name='bNorm_'+str(i)))
        layers.append(tf.keras.layers.Activation('relu', name='act_'+str(i)))
        layers.append(tf.keras.layers.MaxPooling1D(2, name='max_pool_'+str(i)))
    layers.append(tf.keras.layers.LSTM(lstm_hidden_units, return_sequences=False))
    layers.append(tf.keras.layers.Dropout(0.2, name='dropout_1'))
    layers.append(tf.keras.layers.Dense(n_classes*4, activation='relu', name='dense_1'))
    layers.append(tf.keras.layers.Dropout(0.3, name='dropout_2'))
    layers.append(tf.keras.layers.Dense(n_classes*2, activation='relu', name='dense_2'))
    layers.append(tf.keras.layers.Dropout(0.3, name='dropout_3'))
    layers.append(tf.keras.layers.Dense(n_classes, activation='softmax', name='dense_3'))
    model = tf.keras.models.Sequential(layers)
    print(model.summary())
    return model

# %%
def init_simple_rnn(input_shape):  
    n_classes = 182
    n_hidden = 200
    model = tf.keras.models.Sequential([tf.keras.layers.LSTM(256, input_shape=input_shape, return_sequences=False),
                                        tf.keras.layers.Dropout(0.2),
                                        tf.keras.layers.Dense(n_hidden, kernel_regularizer=tf.keras.regularizers.l2(0.001), activation='relu'),
                                        tf.keras.layers.Dropout(0.2),
                                        tf.keras.layers.Dense(n_classes, activation='softmax')])  

    print(model.summary())
    return model

# %%
reducelr_callback = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_acc',
                                                         factor=0.2,
                                                         patience=5,
                                                         min_delta=0.01,verbose=1)

callbacks_list = [reducelr_callback]

# %%
def build_parallel_crnn(x_train, y_train, x_test, y_test, callbacks):
    n_features = x_train.shape[2]
    n_time_frames = x_train.shape[1]
    opt = tf.keras.optimizers.RMSprop(lr=0.0005)  # Optimizer
    model = init_parallel_crnn((n_time_frames, n_features, 1))
    model.compile(loss='categorical_crossentropy',
                optimizer=opt,
                metrics=['accuracy'])
                
    history = model.fit(numpy.expand_dims(x_train, axis = -1), y_train, epochs=50, batch_size=64, verbose=2, validation_split=0.2, callbacks=callbacks)
    results = model.evaluate(numpy.expand_dims(x_test, axis = -1), y_test, batch_size=128)

# %%
checkpoint = tf.keras.callbacks.ModelCheckpoint(parent_path+'weights/parallel/weights_parallel_crnn.best.h5', monitor='val_acc', verbose=1,
                                      save_best_only=True, mode='max')
callbacks_list.append(checkpoint)
build_parallel_crnn(x_train, y_train, x_test, y_test, callbacks_list)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/init_ops.py:97: calling GlorotUniform.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/init_ops.py:97: calling Orthogonal.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/init_ops.py:97: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input (InputLayer)              [(None, 862, 128, 1) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 860, 128, 16) 64          input[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 430, 64, 16)  0           conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 428, 64, 32)  1568        max_pooling2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 214, 32, 32)  0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 212, 32, 64)  6208        max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 106, 16, 64)  0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 104, 16, 64)  12352       max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 26, 4, 64)    0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 24, 4, 64)    12352       max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 431, 64, 1)   0           input[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 6, 1, 64)     0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 431, 64)      0           max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# flatten (Flatten)               (None, 384)          0           max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# bidirectional (Bidirectional)   (None, 128)          66048       lambda[0][0]
# __________________________________________________________________________________________________
# combine (Concatenate)           (None, 512)          0           flatten[0][0]
#                                                                  bidirectional[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 182)          93366       combine[0][0]
# ==================================================================================================
# Total params: 191,958
# Trainable params: 191,958
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/math_grad.py:1424: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Train on 8611 samples, validate on 2153 samples
# Epoch 1/50
# 8611/8611 - 212s - loss: 4.9912 - acc: 0.0310 - val_loss: 4.9214 - val_acc: 0.0367
# Epoch 2/50
# 8611/8611 - 203s - loss: 4.8848 - acc: 0.0461 - val_loss: 4.8316 - val_acc: 0.0553
# Epoch 3/50
# 8611/8611 - 204s - loss: 4.7330 - acc: 0.0693 - val_loss: 4.6179 - val_acc: 0.0836
# Epoch 4/50
# 8611/8611 - 204s - loss: 4.4701 - acc: 0.0972 - val_loss: 4.3951 - val_acc: 0.1059
# Epoch 5/50
# 8611/8611 - 203s - loss: 4.1955 - acc: 0.1248 - val_loss: 4.2001 - val_acc: 0.1310
# Epoch 6/50
# 8611/8611 - 205s - loss: 3.9615 - acc: 0.1557 - val_loss: 4.1417 - val_acc: 0.1305
# Epoch 7/50
# 8611/8611 - 203s - loss: 3.7715 - acc: 0.1810 - val_loss: 3.9157 - val_acc: 0.1681
# Epoch 8/50
# 8611/8611 - 202s - loss: 3.5811 - acc: 0.2086 - val_loss: 3.9496 - val_acc: 0.1714
# Epoch 9/50
# 8611/8611 - 200s - loss: 3.4116 - acc: 0.2378 - val_loss: 3.7388 - val_acc: 0.2016
# Epoch 10/50
# 8611/8611 - 200s - loss: 3.2436 - acc: 0.2647 - val_loss: 3.8517 - val_acc: 0.1909
# Epoch 11/50
# 8611/8611 - 194s - loss: 3.1044 - acc: 0.2995 - val_loss: 3.5638 - val_acc: 0.2281
# Epoch 12/50
# 8611/8611 - 194s - loss: 2.9518 - acc: 0.3232 - val_loss: 3.6217 - val_acc: 0.2253
# Epoch 13/50
# 8611/8611 - 194s - loss: 2.8317 - acc: 0.3443 - val_loss: 3.5113 - val_acc: 0.2452
# Epoch 14/50
# 8611/8611 - 194s - loss: 2.6882 - acc: 0.3745 - val_loss: 3.5292 - val_acc: 0.2513
# Epoch 15/50
# 8611/8611 - 194s - loss: 2.5595 - acc: 0.4011 - val_loss: 3.5630 - val_acc: 0.2675
# Epoch 16/50
# 8611/8611 - 193s - loss: 2.4382 - acc: 0.4263 - val_loss: 3.3616 - val_acc: 0.2750
# Epoch 17/50
# 8611/8611 - 194s - loss: 2.3378 - acc: 0.4459 - val_loss: 3.6024 - val_acc: 0.2569
# Epoch 18/50
# 8611/8611 - 194s - loss: 2.2357 - acc: 0.4703 - val_loss: 3.4624 - val_acc: 0.2726
# Epoch 19/50
# 8611/8611 - 193s - loss: 2.1356 - acc: 0.4805 - val_loss: 3.4596 - val_acc: 0.2880
# Epoch 20/50
# 8611/8611 - 193s - loss: 2.0497 - acc: 0.5013 - val_loss: 3.3318 - val_acc: 0.2945
# Epoch 21/50
# 8611/8611 - 193s - loss: 1.9535 - acc: 0.5265 - val_loss: 3.5409 - val_acc: 0.2708
# Epoch 22/50
# 8611/8611 - 193s - loss: 1.8696 - acc: 0.5459 - val_loss: 3.6219 - val_acc: 0.2791
# Epoch 23/50
# 8611/8611 - 194s - loss: 1.7864 - acc: 0.5635 - val_loss: 3.6481 - val_acc: 0.2894
# Epoch 24/50
# 8611/8611 - 192s - loss: 1.7105 - acc: 0.5777 - val_loss: 3.5966 - val_acc: 0.2954
# Epoch 25/50
# 8611/8611 - 193s - loss: 1.6320 - acc: 0.5939 - val_loss: 3.5887 - val_acc: 0.2805
# Epoch 26/50
# 8611/8611 - 192s - loss: 1.5735 - acc: 0.6036 - val_loss: 3.5722 - val_acc: 0.2880
# Epoch 27/50
# 8611/8611 - 193s - loss: 1.5068 - acc: 0.6190 - val_loss: 3.9247 - val_acc: 0.2940
# Epoch 28/50
# 8611/8611 - 193s - loss: 1.4440 - acc: 0.6362 - val_loss: 3.8469 - val_acc: 0.2922
# Epoch 29/50
# 8611/8611 - 192s - loss: 1.3907 - acc: 0.6470 - val_loss: 3.6834 - val_acc: 0.2843
# Epoch 30/50
# 8611/8611 - 192s - loss: 1.3222 - acc: 0.6644 - val_loss: 3.6836 - val_acc: 0.3056
# Epoch 31/50
# 8611/8611 - 193s - loss: 1.2592 - acc: 0.6765 - val_loss: 3.8034 - val_acc: 0.3168
# Epoch 32/50
# 8611/8611 - 191s - loss: 1.2108 - acc: 0.6907 - val_loss: 3.8318 - val_acc: 0.2922
# Epoch 33/50
# 8611/8611 - 193s - loss: 1.1469 - acc: 0.7007 - val_loss: 4.2248 - val_acc: 0.2791
# Epoch 34/50
# 8611/8611 - 192s - loss: 1.1064 - acc: 0.7142 - val_loss: 4.4052 - val_acc: 0.2996
# Epoch 35/50
# 8611/8611 - 193s - loss: 1.0555 - acc: 0.7288 - val_loss: 4.3259 - val_acc: 0.3205
# Epoch 36/50
# 8611/8611 - 192s - loss: 1.0015 - acc: 0.7389 - val_loss: 4.1505 - val_acc: 0.3061
# Epoch 37/50
# 8611/8611 - 192s - loss: 0.9587 - acc: 0.7521 - val_loss: 4.5923 - val_acc: 0.3047
# Epoch 38/50
# 8611/8611 - 192s - loss: 0.9264 - acc: 0.7530 - val_loss: 4.1438 - val_acc: 0.3112
# Epoch 39/50
# 8611/8611 - 192s - loss: 0.8710 - acc: 0.7715 - val_loss: 4.2068 - val_acc: 0.2973
# Epoch 40/50
# 8611/8611 - 192s - loss: 0.8372 - acc: 0.7787 - val_loss: 4.4544 - val_acc: 0.2754
# Epoch 41/50
# 8611/8611 - 193s - loss: 0.7997 - acc: 0.7925 - val_loss: 4.3063 - val_acc: 0.3005
# Epoch 42/50
# 8611/8611 - 192s - loss: 0.7615 - acc: 0.7975 - val_loss: 4.8221 - val_acc: 0.3070
# Epoch 43/50
# 8611/8611 - 191s - loss: 0.7202 - acc: 0.8085 - val_loss: 4.9646 - val_acc: 0.2922
# Epoch 44/50
# 8611/8611 - 190s - loss: 0.6975 - acc: 0.8140 - val_loss: 4.7770 - val_acc: 0.2912
# Epoch 45/50
# 8611/8611 - 191s - loss: 0.6664 - acc: 0.8187 - val_loss: 4.5456 - val_acc: 0.3042
# Epoch 46/50
# 8611/8611 - 191s - loss: 0.6270 - acc: 0.8364 - val_loss: 4.8900 - val_acc: 0.3038
# Epoch 47/50
# 8611/8611 - 190s - loss: 0.5902 - acc: 0.8430 - val_loss: 4.8383 - val_acc: 0.3228
# Epoch 48/50
# 8611/8611 - 190s - loss: 0.5736 - acc: 0.8417 - val_loss: 5.0993 - val_acc: 0.2638
# Epoch 49/50
# 8611/8611 - 199s - loss: 0.5427 - acc: 0.8547 - val_loss: 5.3716 - val_acc: 0.2889
# Epoch 50/50
# 8611/8611 - 198s - loss: 0.5136 - acc: 0.8588 - val_loss: 5.1156 - val_acc: 0.2875
# 2690/2690 [==============================] - 8s 3ms/sample - loss: 4.8980 - acc: 0.2900

# %%
def build_crnn(x_train, y_train, x_test, y_test, callbacks):
    n_features = x_train.shape[2]
    n_time_frames = x_train.shape[1]
    opt = tf.keras.optimizers.RMSprop(lr=0.0005)  # Optimizer
    model = init_crnn((n_time_frames, n_features))
    model.compile(loss='categorical_crossentropy',
                optimizer=opt,
                metrics=['accuracy'])
    history = model.fit(x_train, y_train, epochs=50, batch_size=64, verbose=2, validation_split=0.2, callbacks=callbacks)
    results = model.evaluate(x_test, y_test, batch_size=128)
    print('test loss, test acc:', results)

# %%
checkpoint = tf.keras.callbacks.ModelCheckpoint(parent_path+'weights/crnn/weights_crnn.best.h5', monitor='val_acc', verbose=1,
                                      save_best_only=True, mode='max')
callbacks_list.append(checkpoint)
build_crnn(x_train, y_train, x_test, y_test, callbacks_list)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv_0 (Conv1D)              (None, 858, 56)           35896
# _________________________________________________________________
# bNorm_0 (BatchNormalization) (None, 858, 56)           224
# _________________________________________________________________
# act_0 (Activation)           (None, 858, 56)           0
# _________________________________________________________________
# max_pool_0 (MaxPooling1D)    (None, 429, 56)           0
# _________________________________________________________________
# conv_1 (Conv1D)              (None, 425, 56)           15736
# _________________________________________________________________
# bNorm_1 (BatchNormalization) (None, 425, 56)           224
# _________________________________________________________________
# act_1 (Activation)           (None, 425, 56)           0
# _________________________________________________________________
# max_pool_1 (MaxPooling1D)    (None, 212, 56)           0
# _________________________________________________________________
# conv_2 (Conv1D)              (None, 208, 56)           15736
# _________________________________________________________________
# bNorm_2 (BatchNormalization) (None, 208, 56)           224
# _________________________________________________________________
# act_2 (Activation)           (None, 208, 56)           0
# _________________________________________________________________
# max_pool_2 (MaxPooling1D)    (None, 104, 56)           0
# _________________________________________________________________
# conv_3 (Conv1D)              (None, 100, 56)           15736
# _________________________________________________________________
# bNorm_3 (BatchNormalization) (None, 100, 56)           224
# _________________________________________________________________
# act_3 (Activation)           (None, 100, 56)           0
# _________________________________________________________________
# max_pool_3 (MaxPooling1D)    (None, 50, 56)            0
# _________________________________________________________________
# conv_4 (Conv1D)              (None, 46, 56)            15736
# _________________________________________________________________
# bNorm_4 (BatchNormalization) (None, 46, 56)            224
# _________________________________________________________________
# act_4 (Activation)           (None, 46, 56)            0
# _________________________________________________________________
# max_pool_4 (MaxPooling1D)    (None, 23, 56)            0
# _________________________________________________________________
# conv_5 (Conv1D)              (None, 19, 56)            15736
# _________________________________________________________________
# bNorm_5 (BatchNormalization) (None, 19, 56)            224
# _________________________________________________________________
# act_5 (Activation)           (None, 19, 56)            0
# _________________________________________________________________
# max_pool_5 (MaxPooling1D)    (None, 9, 56)             0
# _________________________________________________________________
# lstm_1 (LSTM)                (None, 96)                58752
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 96)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 728)               70616
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 728)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 364)               265356
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 364)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 182)               66430
# =================================================================
# Total params: 577,074
# Trainable params: 576,402
# Non-trainable params: 672
# _________________________________________________________________
# None
# Train on 8611 samples, validate on 2153 samples
# Epoch 1/50
#
# Epoch 00001: val_acc did not improve from 0.04784
#
# Epoch 00001: val_acc improved from -inf to 0.03994, saving model to /content/drive/My Drive/Experimental Projects/Bird Song/weights/crnn/weights_crnn.best.h5
# 8611/8611 - 14s - loss: 5.2289 - acc: 0.0473 - val_loss: 5.2491 - val_acc: 0.0399
# Epoch 2/50
#
# Epoch 00002: val_acc improved from 0.04784 to 0.06642, saving model to /content/drive/My Drive/Experimental Projects/Bird Song/weights/crnn/weights_crnn.best.h5
#
# Epoch 00002: val_acc improved from 0.03994 to 0.06642, saving model to /content/drive/My Drive/Experimental Projects/Bird Song/weights/crnn/weights_crnn.best.h5
# 8611/8611 - 11s - loss: 4.7984 - acc: 0.0910 - val_loss: 4.9198 - val_acc: 0.0664
# Epoch 3/50
#
# Epoch 00003: val_acc improved from 0.06642 to 0.09243, saving model to /content/drive/My Drive/Experimental Projects/Bird Song/weights/crnn/weights_crnn.best.h5
#
# Epoch 00003: val_acc improved from 0.06642 to 0.09243, saving model to /content/drive/My Drive/Experimental Projects/Bird Song/weights/crnn/weights_crnn.best.h5
# 8611/8611 - 11s - loss: 4.4136 - acc: 0.1223 - val_loss: 4.7026 - val_acc: 0.0924
# Epoch 4/50
#
# Epoch 00004: val_acc improved from 0.09243 to 0.12355, saving model to /content/drive/My Drive/Experimental Projects/Bird Song/weights/crnn/weights_crnn.best.h5
#
# Epoch 00004: val_acc improved from 0.09243 to 0.12355, saving model to /content/drive/My Drive/Experimental Projects/Bird Song/weights/crnn/weights_crnn.best.h5
# 8611/8611 - 11s - loss: 4.1416 - acc: 0.1520 - val_loss: 4.3518 - val_acc: 0.1235
# Epoch 5/50
#
# Epoch 00005: val_acc improved from 0.12355 to 0.16256, saving model to /content/drive/My Drive/Experimental Projects/Bird Song/weights/crnn/weights_crnn.best.h5
#
# Epoch 00005: val_acc improved from 0.12355 to 0.16256, saving model to /content/drive/My Drive/Experimental Projects/Bird Song/weights/crnn/weights_crnn.best.h5
# 8611/8611 - 11s - loss: 3.9131 - acc: 0.1773 - val_loss: 4.3295 - val_acc: 0.1626
# Epoch 6/50
#
# Epoch 00006: val_acc did not improve from 0.16256
#
# Epoch 00006: val_acc did not improve from 0.16256
# 8611/8611 - 10s - loss: 3.7433 - acc: 0.1992 - val_loss: 4.1948 - val_acc: 0.1542
# Epoch 7/50
#
# Epoch 00007: val_acc improved from 0.16256 to 0.18300, saving model to /content/drive/My Drive/Experimental Projects/Bird Song/weights/crnn/weights_crnn.best.h5
#
# Epoch 00007: val_acc improved from 0.16256 to 0.18300, saving model to /content/drive/My Drive/Experimental Projects/Bird Song/weights/crnn/weights_crnn.best.h5
# 8611/8611 - 11s - loss: 3.5850 - acc: 0.2169 - val_loss: 4.0165 - val_acc: 0.1830
# Epoch 8/50
#
# Epoch 00008: val_acc did not improve from 0.18300
#
# Epoch 00008: val_acc did not improve from 0.18300
# 8611/8611 - 10s - loss: 3.4591 - acc: 0.2318 - val_loss: 4.5175 - val_acc: 0.1222
# Epoch 9/50
#
# Epoch 00009: val_acc improved from 0.18300 to 0.20019, saving model to /content/drive/My Drive/Experimental Projects/Bird Song/weights/crnn/weights_crnn.best.h5
#
# Epoch 00009: val_acc improved from 0.18300 to 0.20019, saving model to /content/drive/My Drive/Experimental Projects/Bird Song/weights/crnn/weights_crnn.best.h5
# 8611/8611 - 11s - loss: 3.3404 - acc: 0.2542 - val_loss: 3.8769 - val_acc: 0.2002
# Epoch 10/50
#
# Epoch 00010: val_acc did not improve from 0.20019
#
# Epoch 00010: val_acc did not improve from 0.20019
# 8611/8611 - 10s - loss: 3.2350 - acc: 0.2714 - val_loss: 4.0180 - val_acc: 0.1881
# Epoch 11/50
#
# Epoch 00011: val_acc improved from 0.20019 to 0.22202, saving model to /content/drive/My Drive/Experimental Projects/Bird Song/weights/crnn/weights_crnn.best.h5
#
# Epoch 00011: val_acc improved from 0.20019 to 0.22202, saving model to /content/drive/My Drive/Experimental Projects/Bird Song/weights/crnn/weights_crnn.best.h5
# 8611/8611 - 11s - loss: 3.1305 - acc: 0.2908 - val_loss: 3.7559 - val_acc: 0.2220
# Epoch 12/50
#
# Epoch 00012: val_acc did not improve from 0.22202
#
# Epoch 00012: val_acc did not improve from 0.22202
# 8611/8611 - 10s - loss: 3.0240 - acc: 0.3080 - val_loss: 4.6737 - val_acc: 0.1510
# Epoch 13/50
#
# Epoch 00013: val_acc did not improve from 0.22202
#
# Epoch 00013: val_acc did not improve from 0.22202
# 8611/8611 - 10s - loss: 2.9448 - acc: 0.3284 - val_loss: 4.8112 - val_acc: 0.1811
# Epoch 14/50
#
# Epoch 00014: val_acc did not improve from 0.22202
#
# Epoch 00014: val_acc did not improve from 0.22202
# 8611/8611 - 10s - loss: 2.8581 - acc: 0.3506 - val_loss: 4.1374 - val_acc: 0.1728
# Epoch 15/50
#
# Epoch 00015: val_acc improved from 0.22202 to 0.26660, saving model to /content/drive/My Drive/Experimental Projects/Bird Song/weights/crnn/weights_crnn.best.h5
#
# Epoch 00015: val_acc improved from 0.22202 to 0.26660, saving model to /content/drive/My Drive/Experimental Projects/Bird Song/weights/crnn/weights_crnn.best.h5
# 8611/8611 - 11s - loss: 2.7707 - acc: 0.3621 - val_loss: 3.6111 - val_acc: 0.2666
# Epoch 16/50
#
# Epoch 00016: val_acc did not improve from 0.26660
#
# Epoch 00016: val_acc did not improve from 0.26660
# 8611/8611 - 10s - loss: 2.6914 - acc: 0.3765 - val_loss: 3.9042 - val_acc: 0.2327
# Epoch 17/50
#
# Epoch 00017: val_acc did not improve from 0.26660
#
# Epoch 00017: val_acc did not improve from 0.26660
# 8611/8611 - 10s - loss: 2.6325 - acc: 0.3941 - val_loss: 3.8284 - val_acc: 0.2378
# Epoch 18/50
#
# Epoch 00018: val_acc did not improve from 0.26660
#
# Epoch 00018: val_acc did not improve from 0.26660
# 8611/8611 - 10s - loss: 2.5498 - acc: 0.4072 - val_loss: 4.8159 - val_acc: 0.1575
# Epoch 19/50
#
# Epoch 00019: val_acc improved from 0.26660 to 0.26893, saving model to /content/drive/My Drive/Experimental Projects/Bird Song/weights/crnn/weights_crnn.best.h5
#
# Epoch 00019: val_acc improved from 0.26660 to 0.26893, saving model to /content/drive/My Drive/Experimental Projects/Bird Song/weights/crnn/weights_crnn.best.h5
# 8611/8611 - 11s - loss: 2.4696 - acc: 0.4219 - val_loss: 3.5686 - val_acc: 0.2689
# Epoch 20/50
#
# Epoch 00020: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00020: val_acc did not improve from 0.26893
#
# Epoch 00020: val_acc did not improve from 0.26893
# 8611/8611 - 11s - loss: 2.4247 - acc: 0.4315 - val_loss: 3.9394 - val_acc: 0.2466
# Epoch 21/50
#
# Epoch 00021: val_acc improved from 0.26893 to 0.37715, saving model to /content/drive/My Drive/Experimental Projects/Bird Song/weights/crnn/weights_crnn.best.h5
#
# Epoch 00021: val_acc improved from 0.26893 to 0.37715, saving model to /content/drive/My Drive/Experimental Projects/Bird Song/weights/crnn/weights_crnn.best.h5
# 8611/8611 - 11s - loss: 2.1095 - acc: 0.5084 - val_loss: 3.0162 - val_acc: 0.3771
# Epoch 22/50
#
# Epoch 00022: val_acc improved from 0.37715 to 0.39248, saving model to /content/drive/My Drive/Experimental Projects/Bird Song/weights/crnn/weights_crnn.best.h5
#
# Epoch 00022: val_acc improved from 0.37715 to 0.39248, saving model to /content/drive/My Drive/Experimental Projects/Bird Song/weights/crnn/weights_crnn.best.h5
# 8611/8611 - 11s - loss: 1.9838 - acc: 0.5334 - val_loss: 3.0697 - val_acc: 0.3925
# Epoch 23/50
#
# Epoch 00023: val_acc improved from 0.39248 to 0.40084, saving model to /content/drive/My Drive/Experimental Projects/Bird Song/weights/crnn/weights_crnn.best.h5
#
# Epoch 00023: val_acc improved from 0.39248 to 0.40084, saving model to /content/drive/My Drive/Experimental Projects/Bird Song/weights/crnn/weights_crnn.best.h5
# 8611/8611 - 11s - loss: 1.9546 - acc: 0.5381 - val_loss: 2.9464 - val_acc: 0.4008
# Epoch 24/50
#
# Epoch 00024: val_acc did not improve from 0.40084
#
# Epoch 00024: val_acc did not improve from 0.40084
# 8611/8611 - 10s - loss: 1.9168 - acc: 0.5453 - val_loss: 3.0687 - val_acc: 0.3962
# Epoch 25/50
#
# Epoch 00025: val_acc did not improve from 0.40084
#
# Epoch 00025: val_acc did not improve from 0.40084
# 8611/8611 - 10s - loss: 1.8792 - acc: 0.5515 - val_loss: 3.0469 - val_acc: 0.3990
# Epoch 26/50
#
# Epoch 00026: val_acc did not improve from 0.40084
#
# Epoch 00026: val_acc did not improve from 0.40084
# 8611/8611 - 10s - loss: 1.8397 - acc: 0.5622 - val_loss: 3.0969 - val_acc: 0.3994
# Epoch 27/50
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 2.0000000949949027e-05.
#
# Epoch 00027: val_acc did not improve from 0.40084
#
# Epoch 00027: val_acc did not improve from 0.40084
# 8611/8611 - 10s - loss: 1.8279 - acc: 0.5639 - val_loss: 3.1262 - val_acc: 0.3948
# Epoch 28/50
#
# Epoch 00028: val_acc improved from 0.40084 to 0.41105, saving model to /content/drive/My Drive/Experimental Projects/Bird Song/weights/crnn/weights_crnn.best.h5
#
# Epoch 00028: val_acc improved from 0.40084 to 0.41105, saving model to /content/drive/My Drive/Experimental Projects/Bird Song/weights/crnn/weights_crnn.best.h5
# 8611/8611 - 11s - loss: 1.7283 - acc: 0.5903 - val_loss: 3.0831 - val_acc: 0.4111
# Epoch 29/50
#
# Epoch 00029: val_acc improved from 0.41105 to 0.41338, saving model to /content/drive/My Drive/Experimental Projects/Bird Song/weights/crnn/weights_crnn.best.h5
#
# Epoch 00029: val_acc improved from 0.41105 to 0.41338, saving model to /content/drive/My Drive/Experimental Projects/Bird Song/weights/crnn/weights_crnn.best.h5
# 8611/8611 - 11s - loss: 1.7004 - acc: 0.6006 - val_loss: 3.0972 - val_acc: 0.4134
# Epoch 30/50
#
# Epoch 00030: val_acc did not improve from 0.41338
#
# Epoch 00030: val_acc did not improve from 0.41338
# 8611/8611 - 10s - loss: 1.7097 - acc: 0.5902 - val_loss: 3.1227 - val_acc: 0.4041
# Epoch 31/50
#
# Epoch 00031: val_acc did not improve from 0.41338
#
# Epoch 00031: val_acc did not improve from 0.41338
# 8611/8611 - 10s - loss: 1.6737 - acc: 0.6011 - val_loss: 3.1056 - val_acc: 0.4101
# Epoch 32/50
#
# Epoch 00032: val_acc did not improve from 0.41338
#
# Epoch 00032: val_acc did not improve from 0.41338
# 8611/8611 - 10s - loss: 1.6848 - acc: 0.5953 - val_loss: 3.1370 - val_acc: 0.4101
# Epoch 33/50
#
# Epoch 00033: ReduceLROnPlateau reducing learning rate to 4.000000262749381e-06.
#
# Epoch 00033: val_acc did not improve from 0.41338
#
# Epoch 00033: val_acc did not improve from 0.41338
# 8611/8611 - 10s - loss: 1.6740 - acc: 0.5970 - val_loss: 3.1286 - val_acc: 0.4120
# Epoch 34/50
#
# Epoch 00034: val_acc improved from 0.41338 to 0.41663, saving model to /content/drive/My Drive/Experimental Projects/Bird Song/weights/crnn/weights_crnn.best.h5
#
# Epoch 00034: val_acc improved from 0.41338 to 0.41663, saving model to /content/drive/My Drive/Experimental Projects/Bird Song/weights/crnn/weights_crnn.best.h5
# 8611/8611 - 11s - loss: 1.6707 - acc: 0.5953 - val_loss: 3.1432 - val_acc: 0.4166
# Epoch 35/50
#
# Epoch 00035: val_acc did not improve from 0.41663
#
# Epoch 00035: val_acc did not improve from 0.41663
# 8611/8611 - 10s - loss: 1.6546 - acc: 0.6003 - val_loss: 3.1328 - val_acc: 0.4124
# Epoch 36/50
#
# Epoch 00036: val_acc did not improve from 0.41663
#
# Epoch 00036: val_acc did not improve from 0.41663
# 8611/8611 - 10s - loss: 1.6595 - acc: 0.6077 - val_loss: 3.1409 - val_acc: 0.4138
# Epoch 37/50
#
# Epoch 00037: val_acc did not improve from 0.41663
#
# Epoch 00037: val_acc did not improve from 0.41663
# 8611/8611 - 10s - loss: 1.6382 - acc: 0.6074 - val_loss: 3.1300 - val_acc: 0.4148
# Epoch 38/50
#
# Epoch 00038: ReduceLROnPlateau reducing learning rate to 8.000000889296644e-07.
#
# Epoch 00038: val_acc did not improve from 0.41663
#
# Epoch 00038: val_acc did not improve from 0.41663
# 8611/8611 - 10s - loss: 1.6362 - acc: 0.6069 - val_loss: 3.1173 - val_acc: 0.4157
# Epoch 39/50
#
# Epoch 00039: val_acc did not improve from 0.41663
#
# Epoch 00039: val_acc did not improve from 0.41663
# 8611/8611 - 10s - loss: 1.6480 - acc: 0.6095 - val_loss: 3.1431 - val_acc: 0.4166
# Epoch 40/50
#
# Epoch 00040: val_acc did not improve from 0.41663
#
# Epoch 00040: val_acc did not improve from 0.41663
# 8611/8611 - 10s - loss: 1.6307 - acc: 0.6093 - val_loss: 3.1465 - val_acc: 0.4157
# Epoch 41/50
#
# Epoch 00041: val_acc did not improve from 0.41663
#
# Epoch 00041: val_acc did not improve from 0.41663
# 8611/8611 - 10s - loss: 1.6382 - acc: 0.6071 - val_loss: 3.1525 - val_acc: 0.4166
# Epoch 42/50
#
# Epoch 00042: val_acc improved from 0.41663 to 0.41802, saving model to /content/drive/My Drive/Experimental Projects/Bird Song/weights/crnn/weights_crnn.best.h5
#
# Epoch 00042: val_acc improved from 0.41663 to 0.41802, saving model to /content/drive/My Drive/Experimental Projects/Bird Song/weights/crnn/weights_crnn.best.h5
# 8611/8611 - 11s - loss: 1.6273 - acc: 0.6149 - val_loss: 3.1566 - val_acc: 0.4180
# Epoch 43/50
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 1.6000001323845936e-07.
#
# Epoch 00043: val_acc did not improve from 0.41802
#
# Epoch 00043: val_acc did not improve from 0.41802
# 8611/8611 - 10s - loss: 1.6398 - acc: 0.6090 - val_loss: 3.1313 - val_acc: 0.4171
# Epoch 44/50
#
# Epoch 00044: val_acc did not improve from 0.41802
#
# Epoch 00044: val_acc did not improve from 0.41802
# 8611/8611 - 10s - loss: 1.6474 - acc: 0.6108 - val_loss: 3.1503 - val_acc: 0.4157
# Epoch 45/50
#
# Epoch 00045: val_acc did not improve from 0.41802
#
# Epoch 00045: val_acc did not improve from 0.41802
# 8611/8611 - 10s - loss: 1.6277 - acc: 0.6107 - val_loss: 3.1600 - val_acc: 0.4134
# Epoch 46/50
#
# Epoch 00046: val_acc did not improve from 0.41802
#
# Epoch 00046: val_acc did not improve from 0.41802
# 8611/8611 - 10s - loss: 1.6448 - acc: 0.6031 - val_loss: 3.1435 - val_acc: 0.4138
# Epoch 47/50
#
# Epoch 00047: val_acc did not improve from 0.41802
#
# Epoch 00047: val_acc did not improve from 0.41802
# 8611/8611 - 10s - loss: 1.6648 - acc: 0.5982 - val_loss: 3.1369 - val_acc: 0.4152
# Epoch 48/50
#
# Epoch 00048: ReduceLROnPlateau reducing learning rate to 3.200000264769187e-08.
#
# Epoch 00048: val_acc did not improve from 0.41802
#
# Epoch 00048: val_acc did not improve from 0.41802
# 8611/8611 - 10s - loss: 1.6534 - acc: 0.6023 - val_loss: 3.1307 - val_acc: 0.4124
# Epoch 49/50
#
# Epoch 00049: val_acc did not improve from 0.41802
#
# Epoch 00049: val_acc did not improve from 0.41802
# 8611/8611 - 10s - loss: 1.6317 - acc: 0.6122 - val_loss: 3.1496 - val_acc: 0.4152
# Epoch 50/50
#
# Epoch 00050: val_acc did not improve from 0.41802
#
# Epoch 00050: val_acc did not improve from 0.41802
# 8611/8611 - 10s - loss: 1.6440 - acc: 0.6042 - val_loss: 3.1434 - val_acc: 0.4129
# 2690/2690 [==============================] - 2s 685us/sample - loss: 3.0406 - acc: 0.4171
# test loss, test acc: [3.0406473170425814, 0.41710037]

# %%
def build_rnn(x_train, y_train, x_test, y_test, callbacks):
    n_features = x_train.shape[2]
    n_time_frames = x_train.shape[1]
    opt = tf.keras.optimizers.RMSprop(lr=0.0005)  # Optimizer
    model = init_simple_rnn((n_time_frames, n_features))
    model.compile(loss='categorical_crossentropy',
                optimizer=opt,
                metrics=['accuracy'])
    history = model.fit(x_train, y_train, epochs=50, batch_size=64, verbose=2, validation_split=0.2, callbacks=callbacks)
    results = model.evaluate(x_test, y_test, batch_size=128)
    print('test loss, test acc:', results)

# %%
checkpoint = tf.keras.callbacks.ModelCheckpoint(parent_path+'weights/rnn/weights_rnn.best.h5', monitor='val_acc', verbose=1,
                                      save_best_only=True, mode='max')
callbacks_list.append(checkpoint)
build_rnn(x_train, y_train, x_test, y_test, callbacks_list)
